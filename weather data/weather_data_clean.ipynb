# %%
import pandas as pd

# %%
weather_main_cities = pd.read_csv('../data/weather_main_cities_202405100846.csv')

# %%
weather_main_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084 entries, 0 to 1083
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  1084 non-null   object
#  1   weather_tavg  1084 non-null   float64
#  2   weather_tmin  1084 non-null   float64
#  3   weather_tmax  1084 non-null   float64
#  4   weather_prcp  1084 non-null   float64
#  5   weather_snow  813 non-null    float64
#  6   weather_wdir  733 non-null    float64
#  7   weather_wspd  1084 non-null   float64
#  8   weather_wpgt  0 non-null      float64
#  9   weather_pres  904 non-null    float64
#  10  weather_tsun  0 non-null      float64
#  11  station       1084 non-null   int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 101.8+ KB

# %%
weather_main_cities.sample(20)
# Out:
#      weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp
# 67     2015-12-09           6.9           1.1          12.8           0.0  \
# 797    2017-12-16           2.6          -3.8           8.9           0.0
# 399    2016-02-08          -1.7          -7.7           3.3          13.5
# 919    2016-01-17           3.2          -1.6           5.6           1.8
# 966    2016-12-04           6.2           3.9           8.9           0.0
# 1063   2017-12-11           2.4           0.0           6.1           0.0
# 294    2015-01-24           0.2          -0.5           1.1          18.0
# 840    2015-01-28          -5.1          -9.3           0.6           0.0
# 672    2016-02-10           0.9          -3.2           3.9           0.0
# 729    2017-01-07          -3.8          -7.1          -2.7           0.3
# 688    2016-02-26           3.8          -0.5           4.4           0.0
# 279    2015-01-09          -4.8          -7.1          -1.0           0.3
# ...

# %%
weather_other_cities = pd.read_csv('../data/weather_other_cities_202405100846.csv')weather_other_cities = pd.read_csv('../data/weather_other_cities_202405100846.csv')

# %%
weather_other_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084 entries, 0 to 1083
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  1084 non-null   object
#  1   weather_tavg  1084 non-null   float64
#  2   weather_tmin  1084 non-null   float64
#  3   weather_tmax  1084 non-null   float64
#  4   weather_prcp  1084 non-null   float64
#  5   weather_snow  548 non-null    float64
#  6   weather_wdir  494 non-null    float64
#  7   weather_wspd  1084 non-null   float64
#  8   weather_wpgt  0 non-null      float64
#  9   weather_pres  957 non-null    float64
#  10  weather_tsun  210 non-null    float64
#  11  station       1084 non-null   int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 101.8+ KB

# %%
weather_other_cities.sample(20)
# Out:
#      weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp
# 636    2016-01-05          11.9          10.0          12.8          25.4  \
# 817    2015-01-05          10.7           9.4          12.2           8.1
# 345    2015-12-16          18.7          10.0          21.1          33.0
# 549    2015-01-08          12.0           9.4          15.6           0.0
# 317    2015-02-16          15.4           2.8          20.0           3.8
# 490    2017-02-08          23.6          16.1          30.6           0.0
# 1020   2017-01-27           6.8           2.8          12.2           0.0
# 241    2017-12-02          24.3          20.0          27.8           0.0
# 941    2016-02-08           7.7           3.9          15.0           0.0
# 651    2016-01-20          11.6           8.3          13.3           0.0
# 1072   2017-12-20           4.8           0.0           9.4           3.3
# 60     2015-12-02          25.6          23.3          28.3           7.4
# ...
