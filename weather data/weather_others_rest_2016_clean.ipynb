# %%
import pandas as pd

# %%
weather_other_cities_rest_2016 = pd.read_csv('../data/weather_other_cities_rest_of_2016_202405101142.csv')

# %%
weather_other_cities_rest_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  1100 non-null   object
#  1   weather_tavg  1100 non-null   float64
#  2   weather_tmin  1100 non-null   float64
#  3   weather_tmax  1100 non-null   float64
#  4   weather_prcp  1100 non-null   float64
#  5   weather_snow  550 non-null    float64
#  6   weather_wdir  879 non-null    float64
#  7   weather_wspd  1100 non-null   float64
#  8   weather_wpgt  0 non-null      float64
#  9   weather_pres  1091 non-null   float64
#  10  weather_tsun  242 non-null    float64
#  11  station       1100 non-null   int64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 103.2+ KB

# %%
weather_other_cities_rest_2016.sample(20)
# Out:
#      weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp
# 315    2016-04-10          20.8          15.6          26.7           0.5  \
# 684    2016-07-13          17.0          12.8          25.0           0.0
# 1096   2016-11-27           6.9           5.6           8.3           8.1
# 1038   2016-09-30          12.8           7.8          18.3           0.0
# 40     2016-04-10          22.3          18.3          26.7           0.0
# 884    2016-04-29          11.7           8.9          16.1           0.3
# 629    2016-05-19          15.4          11.7          17.8           0.0
# 363    2016-05-28          22.9          17.8          31.7           0.0
# 610    2016-04-30          14.0           9.4          21.7           0.0
# 388    2016-06-22          28.7          23.9          33.9           0.5
# 168    2016-08-16          29.2          25.6          32.2           7.4
# 22     2016-03-23          23.1          19.4          27.2           0.0
# ...

# %%
weather_other_cities_rest_2016.duplicated().value_counts()
# Out:
# False    1100
# Name: count, dtype: int64

# %% [markdown]
# ## Drop Columns

# %%
weather_other_cities_rest_2016.drop(['weather_wdir', 'weather_wpgt', 'weather_pres', 'weather_tsun'], axis=1, inplace=True)

# %%
weather_other_cities_rest_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  1100 non-null   object
#  1   weather_tavg  1100 non-null   float64
#  2   weather_tmin  1100 non-null   float64
#  3   weather_tmax  1100 non-null   float64
#  4   weather_prcp  1100 non-null   float64
#  5   weather_snow  550 non-null    float64
#  6   weather_wspd  1100 non-null   float64
#  7   station       1100 non-null   int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 68.9+ KB

# %% [markdown]
# ## Convert format of weather_date column to datetime

# %%
weather_other_cities_rest_2016['weather_date'] = pd.to_datetime(weather_other_cities_rest_2016['weather_date'], format='%Y-%m-%d')

# %%
weather_other_cities_rest_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  1100 non-null   datetime64[ns]
#  1   weather_tavg  1100 non-null   float64
#  2   weather_tmin  1100 non-null   float64
#  3   weather_tmax  1100 non-null   float64
#  4   weather_prcp  1100 non-null   float64
#  5   weather_snow  550 non-null    float64
#  6   weather_wspd  1100 non-null   float64
#  7   station       1100 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 68.9 KB

# %% [markdown]
# ## Rename columns

# %%
weather_other_cities_rest_2016.rename(columns={
                                    'weather_date': 'date',
                                    'weather_tavg': 'avg_temp_°C',
                                    'weather_tmin': 'min_temp_°C',
                                    'weather_tmax': 'max_temp_°C',
                                    'weather_prcp': 'rainfall_mm',
                                    'weather_snow': 'snowfall_mm',
                                    'weather_wspd': 'avg_windspeed_kmh'
                                    }, inplace=True)

# %%
weather_other_cities_rest_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1100 non-null   datetime64[ns]
#  1   avg_temp_°C        1100 non-null   float64
#  2   min_temp_°C        1100 non-null   float64
#  3   max_temp_°C        1100 non-null   float64
#  4   rainfall_mm        1100 non-null   float64
#  5   snowfall_mm        550 non-null    float64
#  6   avg_windspeed_kmh  1100 non-null   float64
#  7   station            1100 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 68.9 KB

# %% [markdown]
# ## Create a new column with the names of the cities instead of the code of the station:

# %%
station_names = {
                    74486: 'New York, NY',
                    72509: 'Boston, MA',	
                    72405: 'Washington, DC',
                    72202: 'Miami, FL',
                    72243: 'Houston, TX',
                    72494: 'San Francisco, CA',
                    72793: 'Seattle, WA'
                }

# %%
weather_other_cities_rest_2016['city_name'] = weather_other_cities_rest_2016['station'].map(station_names)

# %%
weather_other_cities_rest_2016.sample(10)
# Out:
#            date  avg_temp_°C  min_temp_°C  max_temp_°C  rainfall_mm
# 726  2016-08-24         16.4         13.9         20.0          0.0  \
# 359  2016-05-24         25.4         22.2         30.0          0.0
# 487  2016-09-29         23.3         17.8         30.0          0.0
# 412  2016-07-16         30.4         25.0         35.6          0.0
# 159  2016-08-07         27.4         23.3         32.2          3.0
# 623  2016-05-13         14.8         12.8         18.9          0.0
# 118  2016-06-27         27.8         25.6         30.6          3.3
# 917  2016-06-01         19.2         12.8         23.3          1.0
# 1087 2016-11-18          7.9          3.9         12.2          0.0
# 671  2016-06-30         15.1         11.7         22.8          0.0
#
#       snowfall_mm  avg_windspeed_kmh  station          city_name
# 726           NaN               22.0    72494  San Francisco, CA
# 359           0.0               19.4    72243        Houston, TX
# ...

# %%
weather_other_cities_rest_2016['city_name'].unique()
# Out:
# array(['Miami, FL', 'Houston, TX', 'San Francisco, CA', 'Seattle, WA'],
#       dtype=object)

# %%
weather_other_cities_rest_2016.drop(['station'], axis=1, inplace=True)

# %%
weather_other_cities_rest_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1100 non-null   datetime64[ns]
#  1   avg_temp_°C        1100 non-null   float64
#  2   min_temp_°C        1100 non-null   float64
#  3   max_temp_°C        1100 non-null   float64
#  4   rainfall_mm        1100 non-null   float64
#  5   snowfall_mm        550 non-null    float64
#  6   avg_windspeed_kmh  1100 non-null   float64
#  7   city_name          1100 non-null   object
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 68.9+ KB

# %%
weather_other_cities_rest_2016.sample(20)
# Out:
#            date  avg_temp_°C  min_temp_°C  max_temp_°C  rainfall_mm
# 132  2016-07-11         30.1         27.2         33.3          0.0  \
# 687  2016-07-16         16.6         12.8         22.8          0.0
# 823  2016-11-29         11.7          6.7         16.1          0.0
# 320  2016-04-15         19.4         14.4         26.1          0.0
# 120  2016-06-29         28.6         25.6         32.2          0.0
# 488  2016-09-30         20.9         14.4         27.2          0.0
# 199  2016-09-16         28.9         25.6         32.8          0.0
# 564  2016-03-15         12.5          8.3         17.8          0.0
# 747  2016-09-14         17.9         13.3         23.3          0.0
# 205  2016-09-22         27.2         23.9         32.2          2.3
# 343  2016-05-08         22.1         17.2         26.1          0.0
# 631  2016-05-21         14.1         12.2         17.8          0.0
# 609  2016-04-29         12.3          8.9         15.6          0.0
# ...

# %% [markdown]
# ## Store DataFrame

# %%
# %store weather_other_cities_rest_2016
# Out:
# Stored 'weather_other_cities_rest_2016' (DataFrame)

# %%
# to recall the stored DataFrame use

# %store -r weather_other_cities_rest_2016

# in the new notebook
