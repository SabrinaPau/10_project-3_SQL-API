# %%
import pandas as pd

# %%
flights_2015_dec = pd.read_csv('./data/FLIGHTS_REPORTING_2015_DEC.csv')
flights_2015_jan = pd.read_csv('./data/FLIGHTS_REPORTING_2015_JAN.csv')
flights_2015_feb = pd.read_csv('./data/FLIGHTS_REPORTING_2015_FEB.csv')

flights_2015 = pd.concat([flights_2015_dec, flights_2015_jan, flights_2015_feb])

flights_2015.sample(20)
# Out:
#         YEAR  MONTH  DAY_OF_MONTH                 FL_DATE ORIGIN  \
# 278992  2015      2            19   2/19/2015 12:00:00 AM    DFW
# 380682  2015      1            26   1/26/2015 12:00:00 AM    BDL
# 417124  2015     12            27  12/27/2015 12:00:00 AM    TRI
# 410950  2015     12            27  12/27/2015 12:00:00 AM    MGM
# 142339  2015     12            10  12/10/2015 12:00:00 AM    DAL
# 212183  2015      2            15   2/15/2015 12:00:00 AM    AUS
# 370050  2015     12            24  12/24/2015 12:00:00 AM    PHX
# 171367  2015      2            12   2/12/2015 12:00:00 AM    EWR
# 197394  2015      1            13   1/13/2015 12:00:00 AM    PVD
# 322552  2015      2            22   2/22/2015 12:00:00 AM    CLT
# 238040  2015      1            16   1/16/2015 12:00:00 AM    HNL
# 107913  2015     12             8   12/8/2015 12:00:00 AM    ATL
# 120943  2015      2             9    2/9/2015 12:00:00 AM    BOS
# ...

# %%
flights_2016_dec = pd.read_csv('./data/FLIGHTS_REPORTING_2016_DEC.csv')
flights_2016_jan = pd.read_csv('./data/FLIGHTS_REPORTING_2016_JAN.csv')
flights_2016_feb = pd.read_csv('./data/FLIGHTS_REPORTING_2016_FEB.csv')

flights_2016 = pd.concat([flights_2016_dec, flights_2016_jan, flights_2016_feb])

flights_2016.sample(20)
# Out:
#         YEAR  MONTH  DAY_OF_MONTH                 FL_DATE ORIGIN  \
# 285983  2016     12            20  12/20/2016 12:00:00 AM    DFW
# 134965  2016      1            10   1/10/2016 12:00:00 AM    DFW
# 340870  2016      1            24   1/24/2016 12:00:00 AM    OGG
# 155828  2016      1            11   1/11/2016 12:00:00 AM    ORD
# 40561   2016     12             3   12/3/2016 12:00:00 AM    RSW
# 54537   2016     12             4   12/4/2016 12:00:00 AM    RIC
# 160562  2016      1            12   1/12/2016 12:00:00 AM    ATL
# 334111  2016      2            23   2/23/2016 12:00:00 AM    SLC
# 248100  2016      1            18   1/18/2016 12:00:00 AM    DEN
# 365712  2016     12            25  12/25/2016 12:00:00 AM    ORD
# 228893  2016      2            16   2/16/2016 12:00:00 AM    SAN
# 119669  2016     12             9   12/9/2016 12:00:00 AM    BOS
# 418410  2016     12            29  12/29/2016 12:00:00 AM    ATL
# ...

# %%
flights_2017_dec = pd.read_csv('./data/FLIGHTS_REPORTING_2017_DEC.csv')
flights_2017_jan = pd.read_csv('./data/FLIGHTS_REPORTING_2017_JAN.csv')
flights_2017_feb = pd.read_csv('./data/FLIGHTS_REPORTING_2017_FEB.csv')

flights_2017 = pd.concat([flights_2017_dec, flights_2017_jan, flights_2017_feb])

flights_2017.sample(20)
# Out:
#         YEAR  MONTH  DAY_OF_MONTH                 FL_DATE ORIGIN  \
# 376489  2017     12            26  12/26/2017 12:00:00 AM    DFW
# 218036  2017      2            16   2/16/2017 12:00:00 AM    BOI
# 61415   2017      1             5    1/5/2017 12:00:00 AM    BNA
# 33334   2017      1             3    1/3/2017 12:00:00 AM    DCA
# 19915   2017      2             2    2/2/2017 12:00:00 AM    DTW
# 36507   2017     12             3   12/3/2017 12:00:00 AM    MCO
# 212219  2017     12            15  12/15/2017 12:00:00 AM    DEN
# 98772   2017      2             7    2/7/2017 12:00:00 AM    SJC
# 198324  2017      2            14   2/14/2017 12:00:00 AM    PHX
# 364991  2017      2            26   2/26/2017 12:00:00 AM    ATL
# 380226  2017     12            26  12/26/2017 12:00:00 AM    LAX
# 57174   2017      1             4    1/4/2017 12:00:00 AM    RDU
# 355168  2017     12            24  12/24/2017 12:00:00 AM    OAK
# ...

# %%
import psycopg2
from sql_functions import get_engine

schema = 'group3'
engine = get_engine()

# %%
table_name_2016 = 'flights_2016'

if engine!=None:
    try:
        flights_2016.to_sql(name=table_name_2016, # Name of SQL table variable
                        con=engine, # Engine or connection
                        schema=schema, # your class schema variable
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name_2016} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# (psycopg2.errors.InvalidSchemaName) schema "group3" does not exist
# LINE 2: CREATE TABLE group3.flights_2016 (
#                      ^
#
# [SQL:
# CREATE TABLE group3.flights_2016 (
# 	"YEAR" BIGINT,
# 	"MONTH" BIGINT,
# 	"DAY_OF_MONTH" BIGINT,
# 	"FL_DATE" TEXT,
# 	"ORIGIN" TEXT,
# 	"ORIGIN_CITY_NAME" TEXT,
# 	"DEST" TEXT,
# 	"DEST_CITY_NAME" TEXT,
# 	"DEP_TIME" FLOAT(53),
# 	"DEP_DELAY" FLOAT(53),
# 	"ARR_TIME" FLOAT(53),
# 	"ARR_DELAY" FLOAT(53),
# 	"CANCELLED" FLOAT(53),
# 	"CANCELLATION_CODE" TEXT,
# 	"DIVERTED" FLOAT(53)
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)
